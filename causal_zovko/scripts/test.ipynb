# %%
import pandas as pd
import numpy as np




df = pd.read_csv(r"C:\Users\Wentao\Desktop\EA_recherche\causal_zovko\data\causal_dataset_1min.csv", parse_dates=["bucket"]).set_index("bucket")
df.columns
# Out:
# Index(['rlop_ask_mean', 'rlop_bid_mean', 'vol_bid_mean', 'vol_ask_mean',
#        'spread_mean', 'imbalance_ob_mean', 'bid_depth_mean', 'ask_depth_mean',
#        'imb_of', 'trade_count', 'trade_volume', 'signed_volume',
#        'abs_signed_volume', 'rlop_ask_mean_lag1', 'rlop_ask_mean_lag2',
#        'rlop_ask_mean_lag5', 'rlop_bid_mean_lag1', 'rlop_bid_mean_lag2',
#        'rlop_bid_mean_lag5', 'vol_bid_mean_lag1', 'vol_bid_mean_lag2',
#        'vol_bid_mean_lag5', 'vol_ask_mean_lag1', 'vol_ask_mean_lag2',
#        'vol_ask_mean_lag5', 'spread_mean_lag1', 'spread_mean_lag2',
#        'spread_mean_lag5', 'imbalance_ob_mean_lag1', 'imbalance_ob_mean_lag2',
#        'imbalance_ob_mean_lag5', 'bid_depth_mean_lag1', 'bid_depth_mean_lag2',
#        'bid_depth_mean_lag5', 'ask_depth_mean_lag1', 'ask_depth_mean_lag2',
#        'ask_depth_mean_lag5', 'imb_of_lag1', 'imb_of_lag2', 'imb_of_lag5',
#        'trade_count_lag1', 'trade_count_lag2', 'trade_count_lag5',
# ...

# %%
dg = pd.read_csv(r"C:\Users\Wentao\Desktop\EA_recherche\causal_zovko\data\features_1min.csv")
dg.columns
# Out:
# Index(['bucket', 'rlop_bid_mean', 'rlop_bid_p90', 'rlop_bid_count',
#        'rlop_ask_mean', 'rlop_ask_p90', 'rlop_ask_count', 'vol_bid_mean',
#        'vol_bid_p90', 'vol_bid_count', 'vol_ask_mean', 'vol_ask_p90',
#        'vol_ask_count', 'trade_count', 'trade_volume', 'signed_volume',
#        'abs_signed_volume', 'imb_of', 'spread_mean', 'mid_mean',
#        'bid_depth_mean', 'ask_depth_mean', 'imbalance_ob_mean',
#        'limit_new_bid_count', 'limit_new_ask_count', 'cancel_bid_count',
#        'cancel_ask_count'],
#       dtype='object')
