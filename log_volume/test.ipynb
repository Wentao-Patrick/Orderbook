# %%
import pandas as pd
import numpy as np

df = pd.read_parquet(r"C:\Users\Wentao\Desktop\EA_recherche\sanofi_book_snapshots_1s.parquet")
df["askvolume1"].describe()
# Out:
# count    30582.000000
# mean       469.513243
# std        361.992308
# min          1.000000
# 25%        194.000000
# 50%        387.000000
# 75%        665.000000
# max       5487.000000
# Name: askvolume1, dtype: float64
